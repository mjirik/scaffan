# %%
# %pylab inline
import numpy as np
import io3d
from pathlib import Path
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pth = io3d.datasets.join_path("medical/processed/delete/metacentrum/SA_20190710-081733_segmentation\PIG-002_J-18-0092_HE/*.npz", get_root=True)

# %%
pth = Path(pth)
pth
pth.exists()
# Out:
# True

# %%
pths = glob.glob(pth)
pths[0]
# Out:
# 'C:\\Users\\Jirik/data/medical/processed/delete/metacentrum/SA_20190710-081733_segmentation\\PIG-002_J-18-0092_HE\\gradient_base_inner_0.npz'

# %%
arr = np.load(pths[0])["arr"]

# %%
imshow(arr)
