# %%
import numpy as np
x = np.linspace(0,20)
import matplotlib.pyplot as plt

y = 2 *(1 / (1 + np.exp(-x))) - 0.5

plt.plot(x,y)

# %%
slope = 10000
x = np.linspace(0,20000, 1000)
y = 1 - np.exp(-x / slope)
plt.plot(x,y)
